# %% [markdown]
# <a href="https://colab.research.google.com/github/EMADUDDINAsdaq/federated-learning-fairness-xray/blob/main/dataset_freezing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Freezing Notebook — CSC8639
# Emaduddin Asdaq Syed Mohammed | MSc Data Science and AI
#
# Freezes the Dirichlet partition and patient-disjoint 85/10/5 split into CSV files
# so all five FL method notebooks (FedAvg, q-FedAvg, Ada-IFFL, GIFAIR-Global, GIFAIR-Per)
# train and evaluate on the exact same data.
#
# Run this once. Nothing beyond this notebook needs to change in the five model notebooks
# except the cell that loads train_clients / val_clients / test_clients.

# %% [markdown]
# ## Cell 1 — Environment Setup

# %%
pip install flwr protobuf
# Out:
# Requirement already satisfied: flwr in /usr/local/lib/python3.12/dist-packages (1.32.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (6.33.6)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.0.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (1.81.1)
# Requirement already satisfied: grpcio-health-checking<2.0.0,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (1.81.1)
# Requirement already satisfied: cryptography<47.0.0,>=46.0.7 in /usr/local/lib/python3.12/dist-packages (from flwr) (46.0.7)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (3.23.0)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from flwr) (0.0.2)
# Requirement already satisfied: typer<0.21.0,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (0.20.1)
# Requirement already satisfied: uv<0.12.0,>=0.11.15 in /usr/local/lib/python3.12/dist-packages (from flwr) (0.11.28)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.4.1)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (1.2.0)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from flwr) (0.12.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (14.3.4)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from flwr) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.34.2)
# Requirement already satisfied: click<9.0.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (8.4.2)
# Requirement already satisfied: packaging<26.0,>=24.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (25.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.45 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.0.51)
# Requirement already satisfied: alembic<2.0.0,>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from flwr) (1.18.5)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2.0.0,>=1.18.1->flwr) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic<2.0.0,>=1.18.1->flwr) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography<47.0.0,>=46.0.7->flwr) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.33.0->flwr) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.33.0->flwr) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.33.0->flwr) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.33.0->flwr) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=14.0.0->flwr) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=14.0.0->flwr) (2.20.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0.45->flwr) (3.5.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.21.0,>=0.13.0->flwr) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography<47.0.0,>=46.0.7->flwr) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->flwr) (0.1.2)

# %%
# !pip install "flwr[simulation]" protobuf -q
print("✓ Libraries installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 MB 8.2 MB/s eta 0:00:00
# ✓ Libraries installed

# %%
import os, json, time, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from sklearn.metrics import roc_auc_score
warnings.filterwarnings('ignore')

print(f"torch : {torch.__version__}")
print(f"numpy : {np.__version__}")
print(f"GPU   : {torch.cuda.is_available()}")
# Out:
# torch : 2.11.0+cpu
# numpy : 2.0.2
# GPU   : False

# %% [markdown]
# ## Cell 2 — Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Cell 3 — Dataset Download (Kaggle)

# %%
import shutil

os.makedirs('/root/.kaggle', exist_ok=True)
shutil.copy('/content/drive/MyDrive/dissertation/kaggle.json',
            '/root/.kaggle/kaggle.json')
os.chmod('/root/.kaggle/kaggle.json', 0o600)

os.system('pip install -q kaggle')
exit_code = os.system('kaggle datasets download -d nih-chest-xrays/data '
                       '--path /content/nih_kaggle --unzip --quiet')

DATASET_PATH = '/content/nih_kaggle'

if exit_code != 0:
    raise RuntimeError(f"Kaggle download failed with exit code {exit_code} — "
                        f"check kaggle.json credentials and dataset name")

n_files = sum(len(files) for _, _, files in os.walk(DATASET_PATH))
print(f"✓ Dataset path: {DATASET_PATH}")
print(f"✓ Files found  : {n_files:,}")
# Out:
# ✓ Dataset path: /content/nih_kaggle
# ✓ Files found  : 112,128

# %% [markdown]
# ## Cell 4 — Image Indexing

# %%
image_path_dict = {}
for folder in sorted(os.listdir(DATASET_PATH)):
    if folder.startswith('images_'):
        img_dir = os.path.join(DATASET_PATH, folder, 'images')
        if os.path.isdir(img_dir):
            for f in os.listdir(img_dir):
                if f.endswith('.png'):
                    image_path_dict[f] = os.path.join(img_dir, f)
print(f"✓ Indexed {len(image_path_dict):,} images")
# Out:
# ✓ Indexed 112,120 images

# %% [markdown]
# ## Cell 5 — Metadata Loading and Cleaning

# %%
df_raw = pd.read_csv(f"{DATASET_PATH}/Data_Entry_2017.csv")

df = df_raw.copy()
df = df.rename(columns={'Patient Gender': 'Patient Sex'})

null_cols = [c for c in df.columns if df[c].isnull().all()]
df = df.drop(columns=null_cols)

df = df[df['Patient Age'] <= 100]

df['label'] = (df['Finding Labels'] != 'No Finding').astype(int)

df['Age Group'] = pd.cut(
    df['Patient Age'],
    bins=[0, 20, 40, 60, 80, 101],
    labels=['0-20', '20-40', '40-60', '60-80', '80+']
)

df['image_path'] = df['Image Index'].map(image_path_dict)
df = df.dropna(subset=['image_path']).reset_index(drop=True)

print(f"✓ Final dataset : {len(df):,} rows")
print(f"  Pathology rate: {df['label'].mean()*100:.1f}%")
# Out:
# ✓ Final dataset : 112,104 rows
#   Pathology rate: 46.2%

# %% [markdown]
# ## Cell 6 — Dirichlet Partition (identical to all 5 training notebooks)

# %%
np.random.seed(42)

NUM_CLIENTS    = 5
ALPHA          = 0.5
HOSPITAL_NAMES = ['Hospital_A', 'Hospital_B', 'Hospital_C',
                  'Hospital_D', 'Hospital_E']

idx_0 = np.where(df['label'].values == 0)[0]
idx_1 = np.where(df['label'].values == 1)[0]
np.random.shuffle(idx_0)
np.random.shuffle(idx_1)

props_0 = np.random.dirichlet(np.repeat(ALPHA, NUM_CLIENTS))
props_1 = np.random.dirichlet(np.repeat(ALPHA, NUM_CLIENTS))

splits_0 = (props_0 * len(idx_0)).astype(int)
splits_1 = (props_1 * len(idx_1)).astype(int)
splits_0[-1] = len(idx_0) - splits_0[:-1].sum()
splits_1[-1] = len(idx_1) - splits_1[:-1].sum()

clients = {}
ptr0, ptr1 = 0, 0
for i, name in enumerate(HOSPITAL_NAMES):
    idx = np.concatenate([
        idx_0[ptr0:ptr0 + splits_0[i]],
        idx_1[ptr1:ptr1 + splits_1[i]]
    ])
    clients[name] = df.iloc[idx].copy().reset_index(drop=True)
    ptr0 += splits_0[i]
    ptr1 += splits_1[i]

for name, data in clients.items():
    print(f"{name}: {len(data):,} images | pathology {data['label'].mean()*100:.1f}%")
print("\n✓ Non-IID partition confirmed")
# Out:
# Hospital_A: 61,505 images | pathology 59.9%
# Hospital_B: 10,655 images | pathology 99.7%
# Hospital_C: 34,936 images | pathology 8.2%
# Hospital_D: 1,495 images | pathology 69.1%
# Hospital_E: 3,513 images | pathology 10.0%
#
# ✓ Non-IID partition confirmed

# %% [markdown]
# ## Cell 7 — Train/Val/Test Split (patient-disjoint, 85/10/5)

# %%
# Same 85/10/5 ratios already used in all five notebooks, but grouped by
# Patient ID so the same patient's scans never appear in both train and test.
# Variable names (train_clients / val_clients / test_clients) are unchanged
# so nothing downstream in any model notebook needs to be edited.

TRAIN_SPLIT = 0.85
VAL_SPLIT   = 0.10
# remaining 0.05 = test

train_clients = {}
val_clients   = {}
test_clients  = {}

for name, data in clients.items():
    patient_ids = data['Patient ID'].unique()
    rng = np.random.RandomState(42)
    rng.shuffle(patient_ids)

    n       = len(patient_ids)
    n_train = int(n * TRAIN_SPLIT)
    n_val   = int(n * VAL_SPLIT)

    train_ids = set(patient_ids[:n_train])
    val_ids   = set(patient_ids[n_train:n_train + n_val])
    test_ids  = set(patient_ids[n_train + n_val:])

    train_clients[name] = data[data['Patient ID'].isin(train_ids)].reset_index(drop=True)
    val_clients[name]   = data[data['Patient ID'].isin(val_ids)].reset_index(drop=True)
    test_clients[name]  = data[data['Patient ID'].isin(test_ids)].reset_index(drop=True)

print(f"{'Client':<14} {'Train':>8} {'Val':>6} {'Test':>6}")
for name in HOSPITAL_NAMES:
    print(f"{name:<14} {len(train_clients[name]):>8,} "
          f"{len(val_clients[name]):>6,} {len(test_clients[name]):>6,}")
# Out:
# Client            Train    Val   Test
# Hospital_A       52,332  6,168  3,005
# Hospital_B        9,074  1,073    508
# Hospital_C       29,813  3,412  1,711
# Hospital_D        1,276    145     74
# Hospital_E        2,997    348    168

# %% [markdown]
# ## Cell 8 — Sanity Check: Confirm No Patient Overlap

# %%
for name in HOSPITAL_NAMES:
    tr = set(train_clients[name]['Patient ID'])
    vl = set(val_clients[name]['Patient ID'])
    te = set(test_clients[name]['Patient ID'])
    overlap = len((tr & vl) | (tr & te) | (vl & te))
    print(f"{name}: patient overlap = {overlap}")
# Out:
# Hospital_A: patient overlap = 0
# Hospital_B: patient overlap = 0
# Hospital_C: patient overlap = 0
# Hospital_D: patient overlap = 0
# Hospital_E: patient overlap = 0

# %% [markdown]
# ## Cell 9 — Save Frozen CSVs to Drive

# %%
SPLIT_DIR = '/content/drive/MyDrive/dissertation/splits'
os.makedirs(SPLIT_DIR, exist_ok=True)

for name in HOSPITAL_NAMES:
    train_clients[name].to_csv(f'{SPLIT_DIR}/{name}_train.csv', index=False)
    val_clients[name].to_csv(f'{SPLIT_DIR}/{name}_val.csv', index=False)
    test_clients[name].to_csv(f'{SPLIT_DIR}/{name}_test.csv', index=False)

print("✓ 15 CSVs saved to:", SPLIT_DIR)
# Out:
# ✓ 15 CSVs saved to: /content/drive/MyDrive/dissertation/splits

# %% [markdown]
# ## Loading in the five training notebooks
#
# Replace the split-generation part of Section 5/6 in each of the five model notebooks
# (FedAvg, q-FedAvg, Ada-IFFL, GIFAIR-Global, GIFAIR-Per) with this single cell.
# Everything else in those notebooks (ChestXrayDataset, build_model, evaluate_client,
# client classes, strategies, training loop) stays exactly as it is.
#
# ```python
# SPLIT_DIR = '/content/drive/MyDrive/dissertation/splits'
# HOSPITAL_NAMES = ['Hospital_A', 'Hospital_B', 'Hospital_C',
#                   'Hospital_D', 'Hospital_E']
#
# train_clients = {n: pd.read_csv(f'{SPLIT_DIR}/{n}_train.csv') for n in HOSPITAL_NAMES}
# val_clients   = {n: pd.read_csv(f'{SPLIT_DIR}/{n}_val.csv')   for n in HOSPITAL_NAMES}
# test_clients  = {n: pd.read_csv(f'{SPLIT_DIR}/{n}_test.csv')  for n in HOSPITAL_NAMES}
#
# for name in HOSPITAL_NAMES:
#     print(f"{name}: {len(train_clients[name]):,} train / "
#           f"{len(val_clients[name]):,} val / {len(test_clients[name]):,} test")
# ```

# %%
test_reload = pd.read_csv(f'{SPLIT_DIR}/Hospital_A_test.csv')
print(test_reload.shape)
print(test_reload[['Patient ID', 'label', 'Age Group', 'Patient Sex', 'image_path']].head(3))
print("label dtype:", test_reload['label'].dtype)

# confirm an actual image opens through the saved path
from PIL import Image
img = Image.open(test_reload['image_path'].iloc[0])
print("✓ Image opens:", img.size)
# Out:
# (3005, 14)
#    Patient ID  label Age Group Patient Sex  \
# 0        4205      0     40-60           M
# 1        1487      0     60-80           F
# 2       26377      0     40-60           F
#
#                                           image_path
# 0  /content/nih_kaggle/images_003/images/00004205...
# 1  /content/nih_kaggle/images_002/images/00001487...
# 2  /content/nih_kaggle/images_011/images/00026377...
# label dtype: int64
# ✓ Image opens: (1024, 1024)

# %%
sample_path = train_clients['Hospital_A']['image_path'].iloc[0]
assert os.path.exists(sample_path), f"Path not found: {sample_path} — re-download dataset first"
print("✓ Image paths resolve correctly in this session")
# Out:
# ✓ Image paths resolve correctly in this session
